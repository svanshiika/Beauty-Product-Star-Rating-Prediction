# %%
# !pip install pandas numpy nltk scikit-learn tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\hp\onedrive\python\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\hp\onedrive\python\lib\site-packages (1.24.3)
# Requirement already satisfied: nltk in c:\users\hp\onedrive\python\lib\site-packages (3.8.1)
# Requirement already satisfied: scikit-learn in c:\users\hp\onedrive\python\lib\site-packages (1.3.0)
# Requirement already satisfied: tqdm in c:\users\hp\onedrive\python\lib\site-packages (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\onedrive\python\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\onedrive\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\onedrive\python\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in c:\users\hp\onedrive\python\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\hp\onedrive\python\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\onedrive\python\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hp\onedrive\python\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\onedrive\python\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: colorama in c:\users\hp\onedrive\python\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\onedrive\python\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Dataset Loading and Preparation

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\HP\Downloads\cleaned_amazon_reviews_2017_2018.csv")  # replace with your actual file path
print(df.shape)        # Print number of rows and columns
print(df.columns)      # Print column names
# Out:
# (57449, 6)
# Index(['asin', 'reviewText', 'summary', 'price', 'brand', 'title'], dtype='object')

# %%
df.head(5)     # Preview the first 5 records
# Out:
#          asin                                         reviewText  \
# 0  B000050FDY  Cleans the razor heads just fine. I found it a...
# 1  B000050FDY       As described. Good price. Delivered on time.
# 2  B000050FDY                                works as advertised
# 3  B000050FDY      A little pricey for the short time they last.
# 4  B000050FDY                            Great Cleaning soultion
#
#                             summary   price  brand  \
# 0                Razor cleanliness.  $11.94  Braun
# 1     Good price. Delivered on time  $11.94  Braun
# 2               works as advertised  $11.94  Braun
# 3  They work well - a little pricey  $11.94  Braun
# 4                        Five Stars  $11.94  Braun
#
#                                                title
# 0  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 1  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 2  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 3  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 4  Braun Clean &amp; Renew Refill Cartridges CCR ...

# %%
# Drop entries with missing review text or star rating
df = df.dropna(subset=['reviewText', 'summary'])

# %%
# Drop duplicate reviews (exact text duplicates) to avoid repeat bias
df = df.drop_duplicates(subset=['reviewText', 'summary'])

# %%
# Convert review text to lowercase
df['reviewText'] = df['reviewText'].str.lower()

# %%
# Remove punctuation using regex: replace any non-word character (not letter, digit, underscore) with space
df['reviewText'] = df['reviewText'].str.replace(r'[^\w\s]', ' ', regex=True)

# %%
# Convert summary column to lowercase
df['summary'] = df['summary'].str.lower()

# Mapping of text to numeric rating
star_mapping = {
    'one star': 1,
    'two stars': 2,
    'three stars': 3,
    'four stars': 4,
    'five stars': 5,
    'one stars': 1,    # In case of plural mismatch
    'two star': 2,
    'three star': 3,
    'four star': 4,
    'five star': 5,
}

# Function to extract numeric star rating from text
def extract_star_rating(text):
    for key in star_mapping:
        if key in text:
            return star_mapping[key]
    return None  # If no match, return None

# Apply the function to create the new column
df['star_review'] = df['summary'].apply(extract_star_rating)

# Drop rows where no star rating was found
df = df.dropna(subset=['star_review'])

# Optionally, convert star_review to int
df['star_review'] = df['star_review'].astype(int)

# Preview the result
print(df[['summary', 'star_review']].head())
# Out:
#       summary  star_review
# 4  five stars            5
# 5  five stars            5
# 6  five stars            5
# 7  four stars            4
# 8  five stars            5

# %%
# Map star ratings to categorical classes
def rating_to_class(rating):
    if rating in [1, 2]:
        return 'low'
    elif rating == 3:
        return 'medium'
    else:
        return 'high'

df['rating_class'] = df['star_review'].apply(rating_to_class)
print(df['rating_class'].value_counts())
# Out:
# rating_class
# high      11580
# low        2850
# medium     1227
# Name: count, dtype: int64

# %%
df.head(5)
df.shape
df.columns
# Out:
# Index(['asin', 'reviewText', 'summary', 'price', 'brand', 'title',
#        'star_review', 'rating_class'],
#       dtype='object')

# %%
df.head(10)
# Out:
#           asin                                  reviewText      summary  \
# 4   B000050FDY                     great cleaning soultion   five stars
# 5   B000050FDY                    great product and price    five stars
# 6   B000050FDY                       great replacement kit   five stars
# 7   B000050FDY  expensive  but it works just as advertised   four stars
# 8   B000050FDY                            excellent value    five stars
# 9   B000050FDY                               great product   four stars
# 10  B000050FDY                          doesn t last long   three stars
# 12  B000050FDY                                  thank you    five stars
# 13  B000050FDY                      used them all the time   five stars
# 16  B000050FDY                         fast and perfect      five stars
#
#      price  brand                                              title  \
# 4   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 5   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 6   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 7   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 8   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 9   $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 10  $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 12  $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 13  $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
# 16  $11.94  Braun  Braun Clean &amp; Renew Refill Cartridges CCR ...
#
#     star_review rating_class
# 4             5         high
# 5             5         high
# 6             5         high
# 7             4         high
# 8             5         high
# 9             4         high
# 10            3       medium
# 12            5         high
# 13            5         high
# 16            5         high

# %% [markdown]
# # LIWC- like feature extraction

# %%
# Define LIWC-like dictionaries (word lists) for each category
i_words_list       = ["i", "me", "my", "mine", "myself"]
positive_words     = ["good", "great", "excellent", "amazing", "love", "fantastic", "happy", "satisfied"]
negative_words     = ["bad", "terrible", "awful", "poor", "hate", "disappointed", "angry", "worst"]
social_words       = ["we", "us", "our", "they", "their", "friends", "family", "everyone"]
cognitive_words    = ["because", "think", "know", "reason", "why", "understand", "thought"]
allure_words       = ["free", "win", "sale", "new", "now", "offer", "best", "guarantee", "exclusive"]
moralization_words = ["should", "must", "ought", "right", "wrong", "honor", "shame", "deserve", "honest"]

# %%
import numpy
import nltk
print("NumPy version:", numpy.__version__)
print("NLTK version:", nltk.__version__)
# Out:
# NumPy version: 1.24.3
# NLTK version: 3.8.1

# %%
import nltk
# Ensure we have a tokenizer (using nltk's word_tokenize or simply split by whitespace)
nltk.download('punkt')  

def count_category_words(text, word_list):
    """Count how many words from word_list appear in the text."""
    # Simple tokenization by splitting on whitespace (text is already lowercased and punctuation removed)
    words = text.split()
    count = 0
    for w in words:
        if w in word_list:
            count += 1
    return count

# Alternatively, one could use nltk.word_tokenize(text) for more robust tokenization.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
from tqdm import tqdm
tqdm.pandas()  # enables progress_apply on pandas Series

# Create new columns in the DataFrame for each LIWC-like feature count
df['i_words_count']       = df['reviewText'].progress_apply(lambda x: count_category_words(x, i_words_list))
df['positive_tone_count'] = df['reviewText'].progress_apply(lambda x: count_category_words(x, positive_words))
df['negative_tone_count'] = df['reviewText'].progress_apply(lambda x: count_category_words(x, negative_words))
df['social_words_count']  = df['reviewText'].progress_apply(lambda x: count_category_words(x, social_words))
df['cognitive_proc_count']= df['reviewText'].progress_apply(lambda x: count_category_words(x, cognitive_words))
df['allure_count']        = df['reviewText'].progress_apply(lambda x: count_category_words(x, allure_words))
df['moralization_count']  = df['reviewText'].progress_apply(lambda x: count_category_words(x, moralization_words))
# Out:
# 100%|██████████| 15657/15657 [00:00<00:00, 163056.97it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 204803.42it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 156164.31it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 146322.71it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 194808.15it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 154534.16it/s]
# 100%|██████████| 15657/15657 [00:00<00:00, 172736.81it/s]

# %%
df.head(20)
# Out:
#           asin                                         reviewText  \
# 4   B000050FDY                            great cleaning soultion
# 5   B000050FDY                           great product and price
# 6   B000050FDY                              great replacement kit
# 7   B000050FDY         expensive  but it works just as advertised
# 8   B000050FDY                                   excellent value
# 9   B000050FDY                                      great product
# 10  B000050FDY                                 doesn t last long
# 12  B000050FDY                                         thank you
# 13  B000050FDY                             used them all the time
# 16  B000050FDY                                fast and perfect
# 17  B000050FDY                         convenient and great price
# 18  B000050FDY  they keep the shaver in top operating form for...
# 20  B000050FDY                              theses work very well
# 22  B000050FDY                                 good quality for
# 24  B000050FDY                                       works great
# 26  B000050FDY  my electric shaver is pretty clean  so i guess...
# 27  B000050FDY                                      as advertised
# 31  B000050FDY                                             great
# 32  B000050FDY  good stuff and i love the bigger case sizes av...
# 33  B000050FDY                                               good
#
#         summary   price  brand  \
# 4    five stars  $11.94  Braun
# 5    five stars  $11.94  Braun
# 6    five stars  $11.94  Braun
# 7    four stars  $11.94  Braun
# 8    five stars  $11.94  Braun
# 9    four stars  $11.94  Braun
# 10  three stars  $11.94  Braun
# 12   five stars  $11.94  Braun
# 13   five stars  $11.94  Braun
# 16   five stars  $11.94  Braun
# 17   five stars  $11.94  Braun
# 18   five stars  $11.94  Braun
# 20   five stars  $11.94  Braun
# 22   five stars  $11.94  Braun
# 24   five stars  $11.94  Braun
# 26   five stars  $11.94  Braun
# 27   five stars  $11.94  Braun
# 31   five stars  $11.94  Braun
# 32   five stars  $11.94  Braun
# 33   five stars  $11.94  Braun
#
#                                                 title  star_review  \
# 4   Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 5   Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 6   Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 7   Braun Clean &amp; Renew Refill Cartridges CCR ...            4
# 8   Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 9   Braun Clean &amp; Renew Refill Cartridges CCR ...            4
# 10  Braun Clean &amp; Renew Refill Cartridges CCR ...            3
# 12  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 13  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 16  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 17  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 18  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 20  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 22  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 24  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 26  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 27  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 31  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 32  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
# 33  Braun Clean &amp; Renew Refill Cartridges CCR ...            5
#
#    rating_class  i_words_count  positive_tone_count  negative_tone_count  \
# 4          high              0                    1                    0
# 5          high              0                    1                    0
# 6          high              0                    1                    0
# 7          high              0                    0                    0
# 8          high              0                    1                    0
# 9          high              0                    1                    0
# 10       medium              0                    0                    0
# 12         high              0                    0                    0
# 13         high              0                    0                    0
# 16         high              0                    0                    0
# 17         high              0                    1                    0
# 18         high              0                    0                    0
# 20         high              0                    0                    0
# 22         high              0                    1                    0
# 24         high              0                    1                    0
# 26         high              2                    0                    0
# 27         high              0                    0                    0
# 31         high              0                    1                    0
# 32         high              1                    2                    0
# 33         high              0                    1                    0
#
#     social_words_count  cognitive_proc_count  allure_count  moralization_count
# 4                    0                     0             0                   0
# 5                    0                     0             0                   0
# 6                    0                     0             0                   0
# 7                    0                     0             0                   0
# 8                    0                     0             0                   0
# 9                    0                     0             0                   0
# 10                   0                     0             0                   0
# 12                   0                     0             0                   0
# 13                   0                     0             0                   0
# 16                   0                     0             0                   0
# 17                   0                     0             0                   0
# 18                   1                     0             0                   0
# 20                   0                     0             0                   0
# 22                   0                     0             0                   0
# 24                   0                     0             0                   0
# 26                   0                     0             0                   0
# 27                   0                     0             0                   0
# 31                   0                     0             0                   0
# 32                   0                     0             0                   0
# 33                   0                     0             0                   0
